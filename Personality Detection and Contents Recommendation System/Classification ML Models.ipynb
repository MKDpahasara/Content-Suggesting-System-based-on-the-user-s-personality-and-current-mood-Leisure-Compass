# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("final personality pp dataset1.csv")

# %%
df
# Out:
#          Unnamed: 0  EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  \
# 0                 0   4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0
# 1                 1   3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0
# 2                 2   2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0
# 3                 3   2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0
# 4                 4   3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0
# ...             ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 1015336     1015336   4.0   2.0   4.0   3.0   4.0   3.0   3.0   3.0   3.0
# 1015337     1015337   4.0   3.0   4.0   3.0   3.0   3.0   4.0   4.0   3.0
# 1015338     1015338   4.0   2.0   4.0   3.0   5.0   1.0   4.0   2.0   4.0
# 1015339     1015339   2.0   4.0   3.0   4.0   2.0   2.0   1.0   4.0   2.0
# 1015340     1015340   4.0   2.0   4.0   2.0   4.0   1.0   4.0   2.0   4.0
#
#          ...  OPN8  OPN9  OPN10  all_extroversion  all_neuroticism  \
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#          Unnamed: 0  EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  \
# 0                 0   4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0
# 1                 1   3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0
# 2                 2   2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0
# 3                 3   2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0
# 4                 4   3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0
# ...             ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 1015336     1015336   4.0   2.0   4.0   3.0   4.0   3.0   3.0   3.0   3.0
# 1015337     1015337   4.0   3.0   4.0   3.0   3.0   3.0   4.0   4.0   3.0
# 1015338     1015338   4.0   2.0   4.0   3.0   5.0   1.0   4.0   2.0   4.0
# 1015339     1015339   2.0   4.0   3.0   4.0   2.0   2.0   1.0   4.0   2.0
# 1015340     1015340   4.0   2.0   4.0   2.0   4.0   1.0   4.0   2.0   4.0
#
#          ...  OPN8  OPN9  OPN10  all_extroversion  all_neuroticism  \
# ...

# %%
final_df = df.drop(['highest_trait','all_extroversion','all_neuroticism','all_agreeableness','all_conscientiousness','all_openness'], axis=1)

# %%
final_df.head()
# Out:
#    Unnamed: 0  EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  ...  \
# 0           0   4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0  ...
# 1           1   3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0  ...
# 2           2   2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0  ...
# 3           3   2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0  ...
# 4           4   3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0  ...
#
#    OPN2  OPN3  OPN4  OPN5  OPN6  OPN7  OPN8  OPN9  OPN10  highest_trait_EN
# 0   1.0   4.0   1.0   4.0   1.0   5.0   3.0   4.0    5.0                 2
# 1   2.0   4.0   2.0   3.0   1.0   4.0   2.0   5.0    3.0                 0
# 2   1.0   2.0   1.0   4.0   2.0   5.0   3.0   4.0    4.0                 4
# 3   2.0   5.0   2.0   3.0   1.0   4.0   4.0   3.0    3.0                 4
# 4   1.0   5.0   1.0   5.0   1.0   5.0   3.0   5.0    5.0                 1
#
# [5 rows x 52 columns]

# %% [markdown]
# # sup.L Classification testing

# %%
X = final_df.iloc[:, :-1].values
y =final_df.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
# Out:
# C:\Users\damindu pahasara\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[25623  5096  4473  4575  3424]
#  [ 4232 41706  1981  2234  1662]
#  [ 3651  2635 43140  1775  1341]
#  [ 3377  2279  2072 54265  1504]
#  [ 3897  2698  2665  3173 29912]]
# 0.7681676467106042

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score

# Assuming y_test and y_pred are already defined
# Calculate confusion matrix and accuracy score
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

# Define labels based on unique classes in y_test
labels = np.unique(y_test)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Print accuracy score
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7681676467106042

# %% [markdown]
# ## nive bayes

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[    0  7332  4859 30955    45]
#  [    0 26199  1445 24171     0]
#  [    0  1902 28670 21969     1]
#  [    0     0     0 63497     0]
#  [    0  5882  4244 31641   578]]
# 0.46941078969177946

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score

# Assuming y_test and y_pred are already defined
# Calculate confusion matrix and accuracy score
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

# Define labels based on unique classes in y_test
labels = np.unique(y_test)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Print accuracy score
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.46941078969177946

# %% [markdown]
# ## LR

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[    0     0     0 43191     0]
#  [    0     0     0 51815     0]
#  [    0     0     0 52542     0]
#  [    0     0     0 63497     0]
#  [    0     0     0 42345     0]]
# 0.25058999960535144

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score

# Assuming y_test and y_pred are already defined
# Calculate confusion matrix and accuracy score
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

# Define labels based on unique classes in y_test
labels = np.unique(y_test)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Print accuracy score
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.25058999960535144
